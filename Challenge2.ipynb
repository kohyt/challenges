# %%
''' 
Write a program for a game where the computer generates a
random starting number between 20 and 30.
The player and the computer can remove 1,2 or 3 from the number
in turns. Something like this:

Starting number: 25
How many do you want to remove? 3
22 left
Computer removes 2
20 left
...

The player who has to remove the last value to bring the number
down to 0 is the loser.

1 left
Computer removes 1
You win!

Easy: Get the computer to choose a number between 1â3 at random. 
'''    
import random
number = random.randint(20,30)
print("Starting number: {}".format(number))
player = int(input("How many do you want to remove? "))
if player >= 1 or player <= 3:
    while number > 0:
        number -= player
        if number == 0 or number < 0:
            print("You lose!")
            break
        print("{} left".format(number))
        comp = random.randint(1,3)
        number -= comp
        print("Computer removes {}".format(comp))
        if number == 0 or number < 0:
            print("You win!")
            break
        print("{} left".format(number))
        player = int(input("How many do you want to remove? "))
else:
    print("Invalid input")
# Out:
# Starting number: 21
# How many do you want to remove? 2
# 19 left
# Computer removes 3
# 16 left
# How many do you want to remove? 1
# 15 left
# Computer removes 2
# 13 left
# How many do you want to remove? 3
# 10 left
# Computer removes 1
# 9 left
# How many do you want to remove? 2
# 7 left
# Computer removes 3
# 4 left
# How many do you want to remove? 3
# 1 left
# Computer removes 3
# You win!

# %%
''' 
Write a program for a game where the computer generates a
random starting number between 20 and 30.
The player and the computer can remove 1,2 or 3 from the number
in turns. Something like this:

Starting number: 25
How many do you want to remove? 3
22 left
Computer removes 2
20 left
...

The player who has to remove the last value to bring the number
down to 0 is the loser.

1 left
Computer removes 1
You win!

Hard: Get the computer to employ a strategy to try and win. 
'''
import random
number = random.randint(20,30)
print("Starting number: {}".format(number))
player = int(input("How many do you want to remove? "))
if player >= 1 or player <= 3:
    while number > 0:
        number -= player
        if number == 0 or number < 0:
            print("You lose!")
            break
        print("{} left".format(number))
        comp = (number % 4 - 1) % 4
        number -= comp
        print("Computer removes {}".format(comp))
        if number == 0 or number < 0:
            print("You win!")
            break
        print("{} left".format(number))
        player = int(input("How many do you want to remove? "))
else:
    print("Invalid input")
# Out:
# Starting number: 21
# How many do you want to remove? 3
# 18 left
# Computer removes 1
# 17 left
# How many do you want to remove? 3
# 14 left
# Computer removes 1
# 13 left
# How many do you want to remove? 3
# 10 left
# Computer removes 1
# 9 left
# How many do you want to remove? 3
# 6 left
# Computer removes 1
# 5 left
# How many do you want to remove? 3
# 2 left
# Computer removes 1
# 1 left
# How many do you want to remove? 1
# You lose!

# %%
'''
Write a program for a Higher / Lower guessing game.
The computer randomly generates a sequence of up to 10 numbers
between 1 and 13. The player after seeing each number in turn
has to decide whether the next number is higher or lower.
If you get 10 guesses right you win the game.

Starting number : 12
Higher(H) or lower(L)? L
Next number 8
Higher(H) or lower(L)? L
Next number 11
You lose

Hints
- Use a condition controlled loop (do until, while etc) to control the
game.
- You do not need to remember all 10 numbers, but  just the current and
the next number.
- Remember to keep a count of the number of guesses. 
'''
import random
numbers = []
for i in range(10):
    numbers.append(random.randint(1,13))
print("Starting number : {}".format(numbers[0]))
i = 0
while i <= (len(numbers)-1):
    if numbers[i] < numbers[i+1]:
        answer = "H"
    else:
        answer = "L"
    guess = input("Higher(H) or lower(L)? ")
    print("Next number {}".format(numbers[i+1]))
    if guess.upper() != answer:
        print("You lose")
        break
    i += 1
# Out:
# Starting number : 9
# Higher(H) or lower(L)? L
# Next number 3
# Higher(H) or lower(L)? L
# Next number 6
# You lose

# %%
'''
Extend the above Higher / Lower number guessing game by
- Giving the player two lives
- Allowing only H or L to be entered 
'''
import random
numbers = []
for i in range(10):
    numbers.append(random.randint(1,13))
print("Starting number : {}".format(numbers[0]))
i = 0
lives = 2
while i <= (len(numbers)-1):
    if numbers[i] < numbers[i+1]:
        answer = "H"
    else:
        answer = "L"
    guess = input("Higher(H) or lower(L)? ")
    if guess != "H" and guess != "L":
        print("Invalid input, only 'H' or 'L' can be entered. Try again.")
        guess = input("Higher(H) or lower(L)? ")
    print("Next number {}".format(numbers[i+1]))
    if guess != answer:
        lives -= 1
        print("Wrong answer. Live(s) left = {}".format(lives))
        if lives < 1: 
            print("You lose")
            break
    i += 1
# Out:
# Starting number : 3
# Higher(H) or lower(L)? h
# Invalid input, only 'H' or 'L' can be entered. Try again.
# Higher(H) or lower(L)? H
# Next number 4
# Higher(H) or lower(L)? L
# Next number 5
# Wrong answer. Live(s) left = 1
# Higher(H) or lower(L)? L
# Next number 6
# Wrong answer. Live(s) left = 0
# You lose

# %%
'''
Write a program to count the number of words in a sentence.
The user enters a sentence.
The program outputs the number of words in the sentence.
Hint: Look for spaces and full stops in the string. 
'''
def count(sentence):
    total = len(sentence)
    for i in range(len(sentence)):
        if sentence[i] == " " or sentence[i] == ".":
            total -= 1
    print(total)
        
sentence = input("Enter sentence: ")
count(sentence)
# Out:
# Enter sentence: hello you are
# 11

# %%
'''
Write a program that will display a sentence backwards after being entered.
Note: You may not use the Python list reverse() function. ;)
'''
def reverse(sentence):
    new = ""
    for i in range (len(sentence)):
        new = sentence[i] + new
    print(new)
    
sentence = input("Enter sentence: ")
reverse(sentence)
# Out:
# Enter sentence: hello you are
# era uoy olleh
